# %% [markdown]
# # Задание 4 - PyCaret - открытая low-code библиотека машинного обучения на Python
#
# ## Картунчиков Артем ББМО-01-23
#
# ## Задание
#
# * Импортируйте набор данных 'diabetes'
# * Выполните импорт всех библиотек из модуля classification библиотеки pycaret
# * Настройте эксперимент, цель - значения столбца 'Class variable'
# * Выполните поиск наилучшей модели
# * Определите наиболее значимые признаки
# * Выполните графическое построение наилучшей модели

# %% [markdown]
# Импортируем нужные библиотеки

# %%
from pycaret.regression import *
from pycaret.datasets import get_data
from pycaret.classification import *


all_datasets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %% [markdown]
# Загрузим датасет `diabetes`

# %%
data=get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %% [markdown]
# Настроим эксперимиент, цель начения столбца 'Class variable'

# %%
reg = setup(
    data=data, 
    target='Class variable', 
    train_size=0.8, 
    session_id=10,
    normalize=True
)
# Out:
# <style type="text/css">
# #T_9eedf_row8_col1, #T_9eedf_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9eedf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9eedf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9eedf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9eedf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9eedf_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9eedf_row0_col1" class="data row0 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9eedf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9eedf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9eedf_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_9eedf_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# Выполним поиск наилучшей модели

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_df226 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# Определим самые важные признаки

# %%
top_features = pull()
top_features
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# ridge                    Ridge Classifier    0.7589  0.0000  0.5418  0.7028
# lr                    Logistic Regression    0.7573  0.6504  0.5420  0.6969
# lda          Linear Discriminant Analysis    0.7573  0.6507  0.5418  0.6991
# gbc          Gradient Boosting Classifier    0.7525  0.5887  0.6080  0.6542
# rf               Random Forest Classifier    0.7493  0.5577  0.5511  0.6648
# nb                            Naive Bayes    0.7444  0.5209  0.6082  0.6398
# et                 Extra Trees Classifier    0.7377  0.5811  0.5411  0.6452
# qda       Quadratic Discriminant Analysis    0.7347  0.5639  0.5615  0.6386
# ada                  Ada Boost Classifier    0.7328  0.5722  0.5422  0.6321
# lightgbm  Light Gradient Boosting Machine    0.7328  0.6230  0.5924  0.6232
# svm                   SVM - Linear Kernel    0.7297  0.0000  0.5511  0.6364
# ...

# %% [markdown]
# Выполним графическое построение модели

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
